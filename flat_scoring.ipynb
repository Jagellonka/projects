# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет!👋</b>
#
# Меня зовут Огурлиев Анзор, я буду ревьюером твоего проекта. Сразу хочу предложить тебе общаться на "ты", если тебе это неудобно, скажи мне об этом. Нам предстоит пройти с тобой через тернистый и от того интересный путь анализа данных! Можешь не переживать, я всегда помогу тебе, если у тебя возникнут вопросы)
#
# По ходу твоей работы я буду оставлять свои комментарии, по выполненным тобой шагам. Попрошу тебя не удалять их, так мне будет проще отслеживать твой прогресс в случае повторной проверки.
#
# Очень важно вести диалог и обсуждать те пункты, которые у тебя могли не получиться, поэтому, ты можешь оставлять свои комментарии, и мы обязательно во всем разберемся! Самое главное - выделяй свои комментарии удобным для тебя способом (цвет, рамка), но так, чтобы они отчетлитво отличались от моих комментариев. Так мы ни в чем не запутаемся)
#
# Свои комментарии я буду выделять так: <font color='green'>зеленый</font>, <font color='gold'>желтый</font> и <font color='red'>красный</font> цвет, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Этот комментарий я буду оставлять, если твое решение оптимально для данного шага.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Это не означает, что ты совершил ошибку. Такими комментариями я буду отмечать места, где ты справился с задачей, но её можно решить ещё лучше. Также в таких комментариях я буду оставлять для тебя другие советы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Если решение, которое ты применил на определенном шаге, требует значительных изменений, то я буду оставлять такой комментарий. Тебе нужно будет подумать еще раз как правильным образом решить данный этап. Если ревью содержит такие комментарии, то я не смогу принять проект с первого раза.
# </div>
#
# P.S. В оглавлении комментария ты увидишь `V1` (`V1`, `V2`, `V3`) - это версия моего комментария, которая понадобится нам с тобой, чтобы не запутаться, если потребуется оставить тебе комментарии после первой проверки.

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что начинаешь проект с описания.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# #### Импорт библиотеки pandas и чтение файла.

# %%
import pandas as pd # импортируем библиотеку pandas

data = pd.read_csv('/datasets/real_estate_data.csv') # чтение файла
data.head(10)
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...
# 5  10\t2890000.0\t30.4\t2018-09-10T00:00:00\t1\t\...
# 6  6\t3700000.0\t37.3\t2017-11-02T00:00:00\t1\t\t...
# 7  5\t7915000.0\t71.6\t2019-04-18T00:00:00\t2\t\t...
# 8  20\t2900000.0\t33.16\t2018-05-23T00:00:00\t1\t...
# 9  18\t5400000.0\t61.0\t2017-02-26T00:00:00\t3\t2...

# %% [markdown]
# В файле знак разделитель `\t`, прочтём файл с сепаратором.

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') # чтение файла с сепаратором
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# #### Знакомство с датасетом.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Датасет содержит 22 столбца и 23699 строк. Построим гистограмму распределения.

# %%
data.hist(figsize=(9, 12));

# %% [markdown]
# Датасет содержит информацию об объявлениях. Каждая строчка — одно объявление.

# %% [markdown]
# Информация включает в себя:
#  - количество фотографий в объявлении (обычно до 20);
#  - цена объекта недвижимости (есть аномалии до 5 миллиардов рублей);
#  - общая площадь объекта (в основном до 150 квадратных метров);
#  - день публикации объявления;
#  - количество комнат (в основном до 6);
#  - высота потолка (есть аномалии до 100 метров, в основном распределение до 10 метров);
#  - этажность дома (в основном до 25 этажей);
#  - жилая площадь (есть аномалии до 400 метров, в основном распределение до 100 метров);
#  - этаж квартиры (в основном до 10);
#  - тип жилья (апартаменты/жилое);
#  - студия (да/нет);
#  - планировка (свободная/перекрытия);
#  - площадь кухни (есть аномалии до 100 метров, в основном распределение до 25 метров);
#  - количество балконов (в основном до 4);
#  - населенный пункт;
#  - расстояние до ближайшего аэропорта в метрах (в основном до 50_000 метров);
#  - расстояние до центра города в метрах (в основном до 25_000 метров);
#  - количество парков в радиусе 3_000 метров (в основном до 2);
#  - расстояние до ближайшего парка в метрах (в основном до 1_000 метров);
#  - количество прудов в радиусе 3_000 метров (в основном до 2);
#  - расстояние до ближайшего пруда в метрах (в основном до 1_0000 метров);
#  - длительность публикации объявления в днях (распределение в основном до 1000 дней).

# %% [markdown]
# В датасете 23699 строк и 22 колонки.

# %% [markdown]
# <font color='orange'> Составил краткое описание </font>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Стоит после того, как ты рассмотрел данные, составить их краткое описание.
#
# Нужно также построить гистограммы распределений столбцов датафрейма.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно доработал.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Работа с пропусками

# %%
data.isna().sum() # подсчет пропусков
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# ##### Локация

# %% [markdown]
# Удалим строки с пропусками локации, их немного, а предполагать локацию по расстоянию до центра и аэропортов слишком трудоёмкая задача для 49 объектов.

# %%
data = data[~data['locality_name'].isna()] # удаляем строки без указания локации
data['locality_name'].isna().sum() # проверяем
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все верно.

# %% [markdown]
# ##### Тип жилья

# %% [markdown]
# Предположим, что пропуски в `is_apartment` означает, что жилье жилое.

# %%
data['is_apartment'].fillna(False, inplace=True) # заполняем пропуски значением False
data['is_apartment'].isna().sum() # проверяем
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно.

# %% [markdown]
# ##### Высота потолков

# %% [markdown]
# Минимальная высота для жилых помещений составляет 2.5 метров. Высота апартаментов может быть и 1 метр и 10 метров. Часто апартаменты под проживание человека делают двухэтажной планировки, чтобы расширить площадь за счёт высоты. Коммерческие помещения на первых этажах тоже могут быть высотой в два средних этажа. Предположим, что в задаче все объекты предназначены для проживания человека и возьмем медианное значение в каждой категории.
# Но сначала приведем столбец `is_apartment` к типу Bool.

# %%
data['is_apartment'] = data['is_apartment'].astype(bool) # приводим столбец к типу Bool
# заполняем пропуски высоты потолка медианным значением в зависимости от типа жилья
data['ceiling_height'].fillna(data.groupby('is_apartment')['ceiling_height'].transform('median'), inplace=True)
data['ceiling_height'].isna().sum() # проверяем
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно обработал пропуски в признаке высоты потолков.

# %% [markdown]
# ##### Количество этажей в доме

# %% [markdown]
# Пропусков всего 86, лучше их удалить.

# %%
data = data.dropna(subset=['floors_total']) # заполняем пропуски
data['floors_total'].isna().sum() # проверка
# Out:
# 0

# %% [markdown]
# <font color='orange'> Удалил объявления с пропусками количества этажей </font>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Пропусков всего 86, можно было удалить эти объявления.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошо

# %% [markdown]
# ##### Жилая площадь и площадь кухни

# %% [markdown]
# Заполним пропуски в этих ячейках исходя из отношения площадей.

# %%
leaving_area_mean = data['living_area'].mean() / data['total_area'].mean() # среднее отношение жилой площади к общей
kitchen_area_mean = data['kitchen_area'].mean() / data['total_area'].mean() # среднее отношение площади кухни к общей
data['living_area'].fillna((data['total_area'] * leaving_area_mean).round(2), inplace=True) # заполняем значения жилой площади
data['kitchen_area'].fillna((data['total_area'] * kitchen_area_mean).round(2), inplace=True) # заполняем площадь кухни
data[['living_area', 'kitchen_area']].isna().sum() # проверка
# Out:
# living_area     0
# kitchen_area    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный способ обработать пропуски в площадях с помощью коэффициентов отношений площадей.

# %% [markdown]
# ##### Балконы

# %% [markdown]
# Предположим, что пропуски в ячейках с балконами говорит о том, что балконов нет. Заполним нулями.

# %%
data['balcony'].fillna(0, inplace=True)
data['balcony'].isna().sum() # проверка
# Out:
# 0

# %% [markdown]
# ##### Пруды, аэропорты, центр и парки

# %% [markdown]
# Пропуски количества прудов и парков в радиусе 3 километра заполним значением ноль.

# %%
data[['parks_around3000', 'ponds_around3000']] = data[['parks_around3000', 'ponds_around3000']].fillna(0)
data[['parks_around3000', 'ponds_around3000']].isna().sum() # проверка
# Out:
# parks_around3000    0
# ponds_around3000    0
# dtype: int64

# %% [markdown]
# Проверим пустые значения расстояний до парков и прудов, когда их количество не равно нулю.

# %%
print(data.query('parks_around3000 > 0')['parks_nearest'].isna().sum())
data.query('ponds_around3000 > 0')['ponds_nearest'].isna().sum()
# Out:
# 0
# 0

# %% [markdown]
# Пропусков нет, значит они есть только при значении `0` в столбцах `parks_around3000` и `ponds_around3000`.
# При этом можно обнаружить несколько определенных значений при значении `parks_around3000` равных 0.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Параметры выше тоже обработал верно.

# %%
data.query('parks_around3000 == 0 & ~parks_nearest.isna()')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1590              3   7500000.0        70.0  2017-07-11T00:00:00      2
# 10959             9   3000000.0        31.1  2017-03-21T00:00:00      1
# 19208            17  14950000.0       187.0  2017-10-12T00:00:00      5
# 19430             9   3900000.0        30.5  2018-02-22T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 1590             2.65          18.0         37.0     13         False  ...
# 10959            2.65           5.0         17.7      2         False  ...
# 19208            3.00           2.0         80.0      2         False  ...
# 19430            2.60           5.0         16.5      1         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 1590           10.0      0.0  Санкт-Петербург           14878.0
# 10959           5.5      0.0  Санкт-Петербург           14821.0
# ...

# %% [markdown]
# Всего четыре строки, которые не сыграют никакой роли. При отсутствии парков и прудов рядом, расстояние до них укажем 0.

# %%
data.loc[data['parks_around3000'] == 0, 'parks_nearest'] = 0
data.loc[data['ponds_around3000'] == 0, 'ponds_nearest'] = 0
data[['parks_around3000', 'ponds_around3000']].isna().sum() # проверка
# Out:
# parks_around3000    0
# ponds_around3000    0
# dtype: int64

# %% [markdown]
# Расстояние до аэропорта возьмем медианное от названия локации. Надо найти неявные дубликаты в названиях.

# %%
data['locality_name'].nunique() # смотрим сколько уникальных значений в названиях топонимов
# Out:
# 364

# %% [markdown]
# Для удобства заменим `ё` на `е`, а также уменьшим регистр.

# %%
data['locality_name'] = data['locality_name'].str.lower() # уменьшаем регистр названий
data['locality_name'] = data['locality_name'].str.replace('ё', 'е') # меняем ё на е
data['locality_name']
# Out:
# 0            санкт-петербург
# 1             поселок шушары
# 2            санкт-петербург
# 3            санкт-петербург
# 4            санкт-петербург
#                 ...
# 23694        санкт-петербург
# 23695                  тосно
# 23696       село рождествено
# 23697        санкт-петербург
# 23698    поселок новый учхоз
# Name: locality_name, Length: 23650, dtype: object

# %% [markdown]
# Составим словарь из слов в названиях локаций и посчитаем их количество.

# %%
locality_name_list = data['locality_name'].to_list() # создаем список из топонимов
locality_name_dict = {} # объявляем словарь для хранения слов из топонимов
for locality_name in locality_name_list: # создаем цикл, в котором проходим по элементам списка из топонимов
    splitted_name = locality_name.split() # разбиваем каждое название населенного пункта на отдельные слова
    for name in splitted_name: # создаем подцикл, в котором проходим по словам из каждого названия населенного пункта
        locality_name_dict[name] = locality_name_dict.get(name, 0) + 1 # записываем в словарь слова и подсчитываем их количество
locality_name_dict
# Out:
# {'санкт-петербург': 15721,
#  'поселок': 2660,
#  'шушары': 440,
#  'городской': 187,
#  'янино-1': 68,
#  'парголово': 327,
#  'мурино': 590,
#  'ломоносов': 133,
#  'сертолово': 142,
#  'петергоф': 201,
#  'пушкин': 369,
#  'деревня': 945,
#  'кудрово': 472,
#  'коммунар': 89,
#  'колпино': 338,
#  'городского': 363,
#  'типа': 363,
#  'красный': 8,
#  'бор': 101,
#  'гатчина': 307,
#  'федоровское': 15,
#  'выборг': 237,
#  'кронштадт': 96,
#  'кировск': 84,
#  'новое': 144,
#  'девяткино': 144,
#  'металлострой': 66,
#  'лебяжье': 15,
#  'сиверский': 29,
#  'молодцово': 9,
#  'кузьмоловский': 35,
#  'садовое': 4,
#  'товарищество': 5,
#  'новая': 15,
#  'ропша': 2,
#  'павловск': 38,
#  'пикколово': 1,
#  'всеволожск': 398,
#  'волхов': 111,
#  'кингисепп': 104,
#  'приозерск': 66,
#  'сестрорецк': 183,
#  'куттузи': 7,
#  'аннино': 16,
#  'ефимовский': 3,
#  'плодовое': 5,
#  'заклинье': 3,
#  'торковичи': 3,
#  'первомайское': 8,
#  'красное': 178,
#  'село': 210,
# ...

# %% [markdown]
# Словарь выше нужен, чтобы удобно было рассмотреть какие слова вообще используются в названиях. Удалим из названий слова по типу: 'поселок', 'городского' и т.д

# %%
# создаем список из слов, которые удалим из столбца с названиями
undue_words = ['поселок ', 'городской ', 'деревня ', 'городского ', 'типа ', 'садовое ', 'товарищество ', 'село ']
for word in undue_words: # создаем цикл и проходим по каждому слову из списка выше
    data['locality_name'] = data['locality_name'].str.replace(word, '') # удаляем слово из названий населенных пунктов
data['locality_name'].nunique() # смотрим сколько осталось уникальных значений
# Out:
# 309

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Неявные дубликаты обработал абсолютно верно, молодец!

# %%
# заполняем пропуски до аэропорта по медианному значению, в зависимости от населенного пункта
data['airports_nearest'].fillna(data.groupby('locality_name')['airports_nearest'].transform('median'), inplace=True)
data['airports_nearest'].isna().sum() # проверяем
# Out:
# 4829

# %% [markdown]
# Большая часть осталась незаполненная, посмотрим в каких населенных пунктах не указано расстояние до аэропорта.

# %%
data[data['airports_nearest'].isna()]['locality_name'].unique()
# Out:
# array(['янино-1', 'сертолово', 'кудрово', 'коммунар', 'красный бор',
#        'гатчина', 'федоровское', 'выборг', 'кировск', 'новое девяткино',
#        'лебяжье', 'сиверский', 'молодцово', 'кузьмоловский',
#        'новая ропша', 'пикколово', 'всеволожск', 'волхов', 'кингисепп',
#        'приозерск', 'куттузи', 'аннино', 'ефимовский', 'плодовое',
#        'заклинье', 'торковичи', 'первомайское', 'сясьстрой', 'старая',
#        'лесколово', 'новый свет', 'сланцы', 'путилово', 'ивангород',
#        'шлиссельбург', 'никольское', 'сосновый бор', 'оржицы', 'кальтино',
#        'романовка', 'бугры', 'рощино', 'кириши', 'луга', 'волосово',
#        'отрадное', 'павлово', 'оредеж', 'копорье', 'тихвин', 'победа',
#        'нурма', 'синявино', 'тосно', 'бокситогорск', 'лопухинка',
#        'пикалево', 'терволово', 'советский', 'подпорожье', 'петровское',
#        'токсово', 'сельцо', 'вырица', 'кипень', 'келози', 'вартемяги',
#        'тельмана', 'севастьяново', 'большая ижора', 'агалатово',
# ...

# %% [markdown]
# Получился довольно большой список из различных топонимов в Ленинградской области. Примем расстояние до аэропорта равным нулю.

# %%
data['locality_name'] = data['locality_name'].str.title() # вернули большие буквы названиям
data['airports_nearest'].fillna(0, inplace=True) # заполнили нулями пропуски до аэропорта
data.isna().sum() # проверяем
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             0
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest           0
# cityCenters_nearest     5511
# parks_around3000           0
# parks_nearest              0
# ponds_around3000           0
# ponds_nearest              0
# days_exposition         3180
# dtype: int64

# %% [markdown]
# Осталось заполнить пропуски до центра города, посмотрим какие строки и города в этих пропусках. Но сначала приведем название столбца в нормальный вид.

# %%
data.rename(columns={'cityCenters_nearest':'city_centers_nearest'}, inplace=True)
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
data[data['city_centers_nearest'].isna()]['locality_name'].unique()
# Out:
# array(['Янино-1', 'Мурино', 'Сертолово', 'Кудрово', 'Коммунар',
#        'Красный Бор', 'Гатчина', 'Федоровское', 'Выборг', 'Кировск',
#        'Новое Девяткино', 'Санкт-Петербург', 'Лебяжье', 'Сиверский',
#        'Молодцово', 'Кузьмоловский', 'Новая Ропша', 'Пикколово',
#        'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск', 'Куттузи',
#        'Аннино', 'Ефимовский', 'Плодовое', 'Заклинье', 'Торковичи',
#        'Первомайское', 'Сясьстрой', 'Старая', 'Лесколово', 'Новый Свет',
#        'Сланцы', 'Путилово', 'Ивангород', 'Шлиссельбург', 'Никольское',
#        'Сосновый Бор', 'Оржицы', 'Кальтино', 'Романовка', 'Бугры',
#        'Рощино', 'Кириши', 'Луга', 'Волосово', 'Отрадное', 'Павлово',
#        'Оредеж', 'Копорье', 'Тихвин', 'Победа', 'Нурма', 'Синявино',
#        'Шушары', 'Тосно', 'Бокситогорск', 'Лопухинка', 'Пикалево',
#        'Терволово', 'Советский', 'Подпорожье', 'Петровское', 'Токсово',
#        'Сельцо', 'Вырица', 'Кипень', 'Келози', 'Вартемяги', 'Тельмана',
# ...

# %% [markdown]
# Петербурга среди них нет, посмотрим, заполнены ли значения для каких-нибудь из н.п., кроме Петербурга.

# %%
data.query('~city_centers_nearest.isna() & locality_name != "Санкт-Петербург"')[['locality_name', 'city_centers_nearest']]
# Out:
#       locality_name  city_centers_nearest
# 1            Шушары               18603.0
# 6         Парголово               19143.0
# 11        Ломоносов               51677.0
# 13         Петергоф               33058.0
# 14           Пушкин               30759.0
# ...             ...                   ...
# 23667    Сестрорецк               33272.0
# 23669       Колпино               30473.0
# 23678        Пушкин               27977.0
# 23685     Ломоносов               51818.0
# 23693      Петергоф               34104.0
#
# [2479 rows x 2 columns]

# %% [markdown]
# Заполним медианным значением в зависимости от населенного пункта и посмотрим сколько осталось незаполненных ячеек.

# %%
data['city_centers_nearest'].fillna(data.groupby('locality_name')['city_centers_nearest'].transform('median'), inplace=True)
data['city_centers_nearest'].isna().sum()
# Out:
# 4829

# %% [markdown]
# Для пустых значений оставим расстояние до центра равным 0.

# %%
data['city_centers_nearest'].fillna(0, inplace=True)
data['city_centers_nearest'].isna().sum() # проверяем
# Out:
# 0

# %% [markdown]
# <font color='orange'> Заполнил нулями пропуски до центра и аэропортов, где нельзя заполнить медианой </font>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# В этом признаке находится расстояние квартиры до центра населенного пункта, в котором эта квартира находится, а не до СПб. Поэтому некорректно таким образом заполнять пропуски. Хорошо, что ты заполнил изначально пропуски медианами по населенным пунктам, но оставшиеся пропуски никак не заполнить, их нужно оставить как есть.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Это далеко не так, лучше оставить пропуски как есть, никак нельзя корректно обработать пропуски. Все картографические данные, вероятно, заполняются автоматически, и пропуски в большинстве параметров появляются одновременно в определенных населенных пунктах. Скорее всего произошел сбой или для этих населенных пунктов в принципе не собирается эта информация.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молоде, что не заполнил общей медианой, можно было пропуски оставшиеся оставить, не заполнять нулями, чтобы затем их не пришлось убирать.

# %% [markdown]
# ##### Количество дней публикации

# %% [markdown]
# Посмотрим есть ли публикации с количеством дней равным нулю.

# %%
data.query('days_exposition == 0')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Таких публикаций нет, справедливо предположить, что это до сих пор активные объявления. После приведения типов, заполним эти ячейки правильно [тут](#days). А пока заполним нулями.

# %%
data['days_exposition'].fillna(0, inplace=True)
data.isna().sum().sum() # проверяем
# Out:
# 0

# %% [markdown]
# <font color='orange'> Ниже переделал количество дней публикации </font>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# А если такие объявления помечаются 1 днем? Нет уверенности, что пропуски это объявления, которые висели меньше 1 дня. Может это до сих пор активные объявления?
#
# Если ты заполнишь пропуски нулями, то статистики занизятся, из-за чего ты сделаешь неправильный вывод о сроке продажи квартир.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все верно

# %% [markdown]
# Пропусков больше нет, можно идти дальше.

# %% [markdown]
# #### Приведение типов

# %% [markdown]
# Посмотрим еще раз на типы данных в таблице.

# %%
data.dtypes
# Out:
# total_images              int64
# last_price              float64
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total            float64
# living_area             float64
# floor                     int64
# is_apartment               bool
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                 float64
# locality_name            object
# airports_nearest        float64
# city_centers_nearest    float64
# parks_around3000        float64
# parks_nearest           float64
# ponds_around3000        float64
# ponds_nearest           float64
# days_exposition         float64
# dtype: object

# %% [markdown]
# В процессе работы с пропусками мы уже успели привести некоторые столбцы к нужному типу данных, осталось несколько:
# `floors_total (количество этажей не может быть вещественным числом), last_price, balcony, parks_around3000, ponds_around3000, days_exposition, first_day_exposition`.

# %% [markdown]
# Дробной части нигде нет, переделываем в целочисленный тип.

# %%
data['floors_total'] = data['floors_total'].astype(int)

# %%
data['balcony'] = data['balcony'].astype(int)

# %%
data['parks_around3000'] = data['parks_around3000'].astype(int)

# %%
data['ponds_around3000'] = data['ponds_around3000'].astype(int)

# %%
data['last_price'] = data['last_price'].astype(int)

# %%
data['days_exposition'] = data['days_exposition'].astype(int)

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'])
data['first_day_exposition']
# Out:
# 0       2019-03-07
# 1       2018-12-04
# 2       2015-08-20
# 3       2015-07-24
# 4       2018-06-19
#            ...
# 23694   2017-03-21
# 23695   2018-01-15
# 23696   2018-02-11
# 23697   2017-03-28
# 23698   2017-07-21
# Name: first_day_exposition, Length: 23650, dtype: datetime64[ns]

# %% [markdown]
# Проверим типы данных еще раз.

# %%
data.dtypes
# Out:
# total_images                     int64
# last_price                       int64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int64
# living_area                    float64
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int64
# locality_name                   object
# airports_nearest               float64
# city_centers_nearest           float64
# parks_around3000                 int64
# parks_nearest                  float64
# ponds_around3000                 int64
# ponds_nearest                  float64
# days_exposition                  int64
# dtype: object

# %% [markdown]
# #####  Расчёт времени публикации

# %% [markdown]
# Когда типы данных приведены, можно узнать последнюю дату в датафрейме.
# <a id='days'></a>

# %%
last_time = data['first_day_exposition'].max()
last_time
# Out:
# Timestamp('2019-05-03 00:00:00')

# %% [markdown]
# Получилось 3 мая 2019 года. Из этого значения будем вычитать значение дня публикации для тех столбцов, где сейчас установлено значение 0 дней.

# %%
data.loc[data['days_exposition'] == 0, 'days_exposition'] = \
(last_time - data.loc[data['days_exposition'] == 0, 'first_day_exposition']).dt.days

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Типы данных подобрал правильно.

# %% [markdown]
# #### Работа с дубликатами

# %% [markdown]
# Поищем дубликаты в датафрейме.

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Полностью похожих строк нет. Один объект может рекламировать как собственник жилья, так и куча агентов, представляющих его интересы, и в каждом из них может быть установлена разная цена и некоторые другие параметры. Поищем дубли по таким критериям: количество этажей, общая площадь, жилая площадь, площадь кухни, количество комнат, высота потолка, этаж, апартаменты, студия, свободной планировки, балконы, название локации.

# %%
benchmark = benchmark = [  # создаем список критериев поиска дубликатов
    'floors_total', 'total_area', 'living_area', 'kitchen_area', 'rooms', 'ceiling_height',
    'floor', 'is_apartment', 'studio', 'open_plan', 'balcony', 'locality_name'
]
duplicates = data[data[benchmark].duplicated(keep=False)] \
.sort_values(by=benchmark) # находим дубликаты по критериям и сортируем
duplicates
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5190              0     8550000        64.5           2015-10-23      3
# 15117             9     6850000        64.5           2017-12-01      3
# 11627            20     9990000        81.4           2018-12-18      3
# 18307            17    12360000        81.4           2018-09-11      3
# 753               6     4500000        81.8           2018-01-01      3
# ...             ...         ...         ...                  ...    ...
# 16721             4     4000000        56.0           2017-07-13      2
# 4907              2     5250000        50.6           2018-08-14      2
# 16940             3     5250000        50.6           2018-08-27      2
# 9721              2     6880000        62.0           2018-06-19      2
# 21344             1     6400000        62.0           2018-02-27      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# По таким критериям поиска нашлось 164 дубля (включая оригинал), рассмотрим их получше. Посмотрим сколько из них из Санкт-Петербурга.

# %%
duplicates.query('locality_name == "Санкт-Петербург"')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5190              0     8550000        64.5           2015-10-23      3
# 15117             9     6850000        64.5           2017-12-01      3
# 11627            20     9990000        81.4           2018-12-18      3
# 18307            17    12360000        81.4           2018-09-11      3
# 2276              2    12500000       150.9           2017-10-02      4
# ...             ...         ...         ...                  ...    ...
# 16721             4     4000000        56.0           2017-07-13      2
# 4907              2     5250000        50.6           2018-08-14      2
# 16940             3     5250000        50.6           2018-08-27      2
# 9721              2     6880000        62.0           2018-06-19      2
# 21344             1     6400000        62.0           2018-02-27      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Можно заметить почти одинаковые значения расстояний до парков и аэропортов и т.д., так что критерии поиска дубликатов выбраны правильно. Как и сказано прежде, цены могут быть разные. Обычно агенства выставляют объект дороже собственника в пользу своей комиссии, удалим те дубликаты, где цена выше.

# %%
benchmark_with_price = benchmark.copy()
benchmark_with_price.append('last_price') # список критериев дубликатов вместе с ценой
duplicates = duplicates.sort_values(by=benchmark_with_price) # сортируем дубликаты по цене
original = duplicates[benchmark].drop_duplicates(keep='first') # удаляем дубликаты и сохраняем первый, который дешевый
duplicates_indexes = list(set(duplicates.index) - set(original.index)) # получаем список индексов дубликатов
data = data.drop(index=duplicates_indexes) # удаляем дубликаты по индексам
data.shape
# Out:
# (23567, 22)

# %% [markdown]
# <font color='orange'> Поменял критерии поиска дубликатов </font>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Почему ты решил, что это объявления по продаже одной и той же квартиры? Нужно сужать тогда столбцы, по которым ты ищешь дубли. Сейчас у схожих квартир может отличаться количество балконов.
#
# Одинаковая цена при схожих других параметрах не показатель, что это дубль. Квартиры в спальных районах, которые почти идентичны по параметрам, очевидно, что и цена будет у них схожа или даже равна.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Сейчас обработка правильная.

# %% [markdown]
# Таким образом осталось 23567 строк датафрейма, дубликаты удалены. Сделаем переиндексацию.

# %%
data = data.reset_index()

# %% [markdown]
# #### Обработка аномальных значений

# %% [markdown]
# ##### Высота

# %% [markdown]
# Начнём с высоты, построим блочную диаграмму.

# %%
data.boxplot(column='ceiling_height', figsize=(12,9));

# %% [markdown]
# Очень большой разброс, очевидно некоторые пользователи ввели высоту потолка без дробной части и получился потолок не 2.7 метра, а 27 метров и т.д. Попробуем посмотреть на площадь квартир с потолками от 25 до 35 метров.

# %%
data.query('25 <= ceiling_height <= 35')['total_area'].mean()
# Out:
# 53.73684210526315

# %% [markdown]
# Средняя площадь действительно получилась "средняя", поделим значения потолков от 25 до 35 метров на 10.

# %%
data.loc[(data['ceiling_height'] <= 35) & (data['ceiling_height'] >= 25), 'ceiling_height'] /= 10

# %% [markdown]
# Посмотрим на распределение еще раз.

# %%
data.boxplot(column='ceiling_height', figsize=(12,9));

# %% [markdown]
# Посмотрим сколько квартир с потолками ниже 2.5 метров и выше 4 метров.

# %%
data.query('ceiling_height < 2.5 | ceiling_height > 4')['ceiling_height'].count()
# Out:
# 129

# %% [markdown]
# Всего 129 квартир, лучше их удалить.

# %%
data = data.query('~(ceiling_height < 2.5 | ceiling_height > 4)')

# %% [markdown]
# <font color='orange'> Удалил аномальные высоты </font>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Если ты хочешь обработать объявления с аномально высокими или низкими потолками, то их стоит удалить. Не надо перезаписывать значения высот, это не обосновано, ты занижаешь высоту, но другие параметры могут тоже быть больше, если это квартира в элитно районе, например.

# %% [markdown]
# Таким образом мы установили ограничение потолков от 2.5 до 4 метров. Далее займемся этажностью.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> И снова все верно, так держать!

# %% [markdown]
# ##### Этаж

# %%
data.boxplot(column='floor', figsize=(12,9));

# %% [markdown]
# Гугление показало, что в Питере есть небоскреб с 82 этажами, на втором месте небоскреб 42 этажа. Проверим высокие здания на принадлежность к Питеру.

# %%
data.query('floor > 30')['locality_name'].hist(figsize=(12,9));

# %% [markdown]
# Похоже на правду, оставим этот столбец нетронутым.

# %% [markdown]
# ##### Площади

# %% [markdown]
# Посмотрим на гистограмму общей площади.

# %%
data['total_area'].hist(figsize=(12,9));

# %% [markdown]
# Распределение оказалось предсказуемым, посмотрим на количество аномально больших квартир.

# %%
data.boxplot(column='total_area')
data.query('total_area > 130').count()
# Out:
# index                   817
# total_images            817
# last_price              817
# total_area              817
# first_day_exposition    817
# rooms                   817
# ceiling_height          817
# floors_total            817
# living_area             817
# floor                   817
# is_apartment            817
# studio                  817
# open_plan               817
# kitchen_area            817
# balcony                 817
# locality_name           817
# airports_nearest        817
# city_centers_nearest    817
# parks_around3000        817
# parks_nearest           817
# ponds_around3000        817
# ponds_nearest           817
# days_exposition         817
# dtype: int64

# %% [markdown]
# Посмотрим на коробчатую диаграмму для больших квартир.

# %%
def compare(data):
    q1 = data.quantile(q=.25) # находим первый квартиль
    q3 = data.quantile(q=.75) # находим третий квартиль
    iqr = q3 - q1 # расстояние между первым и третьим квартилем
    return q3+1.5*iqr # находим верхний диапазон размаха
total_area_compare = compare(data['total_area'])
# строим коробчатую диаграмму для больших квартир
data.query('total_area > @total_area_compare').boxplot(column='total_area', figsize=(9,12));

# %% [markdown]
# Для больших квартир верхняя граница размаха в районе 270 квадратных метров, собственники остальных квартир, видимо, ошиблись на один нолик по примеру высоты. Проверим жилую площадь и площадь кухни квартир и сравним с общей, как минимум их сумма должна быть меньше или равна общей.

# %%
bad_data = data.query('total_area < living_area + kitchen_area')
bad_data['total_area'].count()
# Out:
# 117

# %% [markdown]
# Нашлось 117 квартир с неправильными площадами, но из них только пара аномально большие. Посмотрим на коробчатой диаграме большие квартиры и их жилые площади.

# %%
data.query('total_area > @total_area_compare').boxplot(column=['kitchen_area', 'living_area', 'total_area'], figsize=(9,12));

# %% [markdown]
# Очень похожие картины, наблюдается абсолютная разница, а не относительная. Это наводит на мысль, что пользователи ошиблись во время ввода площади. `Теперь проблема в том, что некоторые пользователи могли ввести неправильно одну площадь, две или три сразу. Надо понять как правильно разделить значения`.

# %% [markdown]
# Найдем верхнюю границу размаха для каждого значения площади. Все площади выше этого значения поделим на 10.

# %%
big_kitchen_area_compare = compare(data.query('total_area > @total_area_compare')['kitchen_area']) # диапазон для кухни
big_living_area_compare = compare(data.query('total_area > @total_area_compare')['living_area']) # диапазон для жилой площади
big_total_area_compare = compare(data.query('total_area > @total_area_compare')['total_area']) # диапазон для общей площади
print(big_kitchen_area_compare, big_living_area_compare, big_total_area_compare)
data.loc[data['kitchen_area'] > big_kitchen_area_compare, 'kitchen_area'] /= 10
data.loc[data['living_area'] > big_living_area_compare, 'living_area'] /= 10
data.loc[data['total_area'] > big_total_area_compare, 'total_area'] /= 10
# Out:
# 47.807500000000005 160.0625 259.8125

# %% [markdown]
# Проверим распределение площадей еще раз.

# %%
data.query('total_area > @total_area_compare').boxplot(column=['kitchen_area', 'living_area', 'total_area'], figsize=(9,12));

# %% [markdown]
# Картина стала лучше, существующие аномалии имеют право на жизнь, проверим еще раз количество квартир с непропорциональными площадами.

# %%
bad_data = data.query('total_area < living_area + kitchen_area')
print(bad_data['total_area'].count())
# Out:
# 173

# %% [markdown]
# Таких квартир стало больше их лучше удалить.

# %%
data = data[data['total_area'] >= data['living_area'] + data['kitchen_area']]
data.shape
# Out:
# (23265, 23)

# %% [markdown]
# Посмотрим на матричное распределение площадей.

# %%
pd.plotting.scatter_matrix(data[['total_area', 'living_area', 'kitchen_area']], figsize=(9, 12));

# %% [markdown]
# Распределение получилось более-менее правильным и видно линейную зависимость между общей площадью и жилой. Площадь кухни в основном расположена до 20 метров, оно и понятно, какой большой квартира не была бы, кухня вырастает не так сильно.
# Остались небольшие аномалии, например небольшая жилая площадь при большой общей площади, избавимся от них, удалим данные, где общая площадь больше 200 и жилая меньше 25.

# %%
data = data[~((data['total_area'] > 200) & (data['living_area'] < 25))]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно обработал.

# %% [markdown]
# ##### Цена

# %%
data.boxplot(column='last_price', figsize=(9, 12));

# %% [markdown]
# Получилось очень много выбросов. Некоторые цены заоблачные, построим график зависимости цены от площади и найдем ошибки.

# %%
data.plot(y='last_price', x='total_area', figsize=(9, 12), kind='scatter');

# %% [markdown]
# Никакой зависимости не видно, возможно пользователи ошиблись при вводе некоторых значений цены. Поставим потолок цены в 100 миллионов.

# %%
data.loc[data['last_price'] > 100_000_000, 'last_price'] /= 100

# %%
data.plot(y='last_price', x='total_area', figsize=(9, 12), kind='scatter');

# %% [markdown]
# Некоторые квартиры подозрительно дешевые, некоторые подозрительно дорогие. Попробуем посмотреть на график через сводную таблицу.

# %%
data.pivot_table(index='total_area', values='last_price', aggfunc='mean') \
.plot(figsize=(9, 12));

# %% [markdown]
# Самый большой разброс начинается после общей площади 150. Это довольно очевидная закономерность, цены на элитное жилье могут очень сильно варьироваться, а еще их тяжело продать, посмотрим количество большого жилья и сколько дней они продавались.

# %%
print(data.query('total_area > 150')['days_exposition'].count())
data.query('total_area > 150')['days_exposition'].mean()
# Out:
# 430
# 351.92093023255813

# %% [markdown]
# Таких объявлений 430 и продаются они в среднем почти год, лучше их удалить, т.к. они слишком сильно влияют на результаты исследования.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Согласен.

# %%
data = data.query('~(total_area > 150)')

# %% [markdown]
# Создадим дополнительные столбцы для лучшего анализа.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим цену за квадратный метр, день недели, месяц, год, тип этажа (первый, последний, другой), расстояние до центра в километрах.

# %%
data['square_price'] = (data['last_price'] / data['total_area']).round(2) # создаем столбец с ценой за квадратный метр
data['day_of_week'] = data['first_day_exposition'].dt.weekday # создаем столбец с номером дня недели
data['month'] = data['first_day_exposition'].dt.month # создаем столбец с номером месяца
data['year'] = data['first_day_exposition'].dt.year # создаем столбец с годом
def floor_type(data): # функция, которая определяет категорию этажа
    if data['floor'] == 1:
        return 'первый'
    if data['floor'] == data['floors_total']:
        return 'последний'
    return 'другой'
data['floor_type'] = data.apply(floor_type, axis=1) # создаем столбец с категорией этажа
data['city_centers_nearest_km'] = (data['city_centers_nearest'] / 1000).round() # создаем столбец с расстоянием до центра в км
# Out:
# /tmp/ipykernel_31/4228824842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['square_price'] = (data['last_price'] / data['total_area']).round(2) # создаем столбец с ценой за квадратный метр
# /tmp/ipykernel_31/4228824842.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['day_of_week'] = data['first_day_exposition'].dt.weekday # создаем столбец с номером дня недели
# /tmp/ipykernel_31/4228824842.py:3: SettingWithCopyWarning:
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Новые столбцы создал правильно, использовал только подходящие методы, так держать!

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Предварительный анализ

# %% [markdown]
# Посмотрим на гистограммы некоторых параметров:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - этаж квартиры;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего аэропорта;
# - расстояние до ближайшего парка;
# - день и месяц публикации объявления

# %%
columns_to_hist = [
    'total_area', 'living_area', 'kitchen_area', 'last_price', 'rooms',
    'ceiling_height', 'floor', 'floor_type', 'floors_total', 'city_centers_nearest',
    'airports_nearest', 'parks_nearest', 'day_of_week', 'month'
]
data[columns_to_hist].hist(figsize=(9,12));

# %% [markdown]
# Выводы:
# - площади имеют похожее распределение, тут все ясно;
# - большинство квартир продаются дешевле 20 миллионов рублей;
# - квартиры до 5 комнат распределены почти равномерно;
# - потолки в основном высотой 2.7 метров:
# - большая часть квартир продается до 10 этажа;
# - чаще всего этажность дома составляет до 14 этажей;
# - большая часть квартир продается в Санкт-Петербурге;
# - аэропорт в основном в пределах 50 км;
# - почти при каждом доме в радиусе километра есть парк;
# - реже всего объявления публикуют в выходные;
# - объявления публикуют чаще всего зимой и реже всего летом.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Лучше проводить анализ каждого параметра по отдельности, строить более подробные диаграммы, можно вывести также статистики и более подробно описать и проанализировать особенности параметров.

# %% [markdown]
# #### Среднее время продажи

# %%
data['days_exposition'].describe()
# Out:
# count    22807.000000
# mean       182.084755
# std        229.044851
# min          0.000000
# 25%         42.000000
# 50%         92.000000
# 75%        231.000000
# max       1618.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].hist(figsize=(9, 12));

# %% [markdown]
# Основную часть квартир продавали в течение первого года.

# %% [markdown]
# Одно время я работал в сфере недвижимости и по своему опыту могу заявить:
#  - на квартиру, выставленную по ликвидной цене, покупатель находится максимум за два месяца (если сделка прозрачная);
#  - цена в объявлении скорее всего не конечная, за кулисами продавец может сделать скидку, причем существенную, которая не отразится в данных;
#  - квартиры не продаются за один день.

# %% [markdown]
# Оставим только те данные, где продажа больше одного дня и меньше 400 дней, кроме тех, которые выставлены в последний день записи датафрейма.

# %%
good_data = data.query('0 < days_exposition < 400 | first_day_exposition == first_day_exposition.max()')
good_data['days_exposition'].describe()
# Out:
# count    19812.000000
# mean       108.989400
# std         97.667022
# min          0.000000
# 25%         35.000000
# 50%         73.000000
# 75%        161.000000
# max        399.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Среднее значение — 108 дней, медиана — 73.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Без учета аномальных продаж все описал верно, молодец! Но объявления, у которых пропуски ты заполнил нулями занижают срок продажи квартир.

# %% [markdown]
# #### Зависимость цены от площади

# %% [markdown]
# Логично предположить, что в среднем, чем больше площадь, тем выше цена.

# %%
good_data.pivot_table(index='total_area', values='last_price').plot(figsize=(9, 12));

# %%
good_data.pivot_table(index='total_area', values='last_price').boxplot(figsize=(9, 12));

# %% [markdown]
# Поддаются анализу площади до 130 м и ценой до 30 миллионов. Оставим эти данные.

# %%
good_data = good_data.query('last_price < 30_000_000 & total_area < 130')
good_data.pivot_table(index='last_price', values='total_area').reset_index() \
.plot(x='last_price', y='total_area', kind='scatter',figsize=(9, 12));

# %% [markdown]
# Зависимость хорошо прослеживается, чем больше, тем выше цена. Проверим то же отношение для жилой площади и кухни.

# %%
good_data.pivot_table(index='last_price', values=['kitchen_area', 'living_area']).reset_index() \
.plot(x='last_price', y='kitchen_area', kind='scatter',figsize=(9, 12));

# %%
good_data.pivot_table(index='last_price', values=['kitchen_area', 'living_area']).reset_index() \
.plot(x='last_price', y='living_area', kind='scatter',figsize=(9, 12));

# %% [markdown]
# <font color='orange'> Сделал диаграммы рассеяния </font>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Лучше построить диаграммы рассеяния для всех параметров площадей. Они покажут как общую тенденцию, так и распределение значений, их легче анализировать, так как будут отсутствовать линии.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Диаграммы построил правильно.

# %% [markdown]
# Зависимость есть у обоих параметров.

# %% [markdown]
# #### Цена и комнатность

# %% [markdown]
# Проверим цену в зависимости от комнатности. Будем проверять по всему датасету, а не только "хорошему", т.к. мы отсеяли почти все большое жилье, которое долго продается.

# %%
rooms_price = data.pivot_table(index='rooms', values='last_price').reset_index()
rooms_price.plot(x='rooms', y='last_price');

# %% [markdown]
# Больше комнат — выше стоимость, это очевидно, но потом цена начинается снижаться и опять растет, проверим почему.

# %% [markdown]
# Сколько квартир с количеством комнат больше 8?

# %%
data.query('rooms > 8')['rooms'].count()
# Out:
# 4

# %% [markdown]
# Всего 4. Проверим их площадь.

# %%
data.query('rooms > 8').groupby('rooms')['total_area'].max()
# Out:
# rooms
# 9     40.0
# 12    90.0
# 15    59.0
# Name: total_area, dtype: float64

# %% [markdown]
# Оказалось, что это просто аномалия, слишком маленькая площадь для такого количества комнат. Посмотрим на график без этих квартир.

# %%
bad_rooms=[9,12,15]
data.query('~rooms.isin(@bad_rooms)').pivot_table(index='rooms', values='last_price').reset_index() \
.plot(x='rooms', y='last_price');

# %% [markdown]
# Видимо отдельные значения слишком сильно влияют на график, т.к. таких больших квартир совсем мало, но в целом зависимость хорошо наблюдается для значений до 8 комнат.

# %% [markdown]
# #### Этаж и цена

# %% [markdown]
# Посмотрим на распределение цены в зависимости от категории этажа.

# %%
floor_price = good_data.pivot_table(index='floor_type', values='last_price').reset_index()
floor_price.plot(x='floor_type', y='last_price');

# %% [markdown]
# Первые этажи ценятся меньше всего, никто не хочет, чтобы тебе глядели в окно, последние этажи стоят в среднем на 600 тысяч меньше средних, есть риск, что протечет крыша.

# %% [markdown]
# #### Время публикации объявления и цена

# %% [markdown]
# Говорят, что чаще недвижимость продается перед Новым Годом, проверим это, заодно и цену. Создадим столбец месяца продажи.

# %%
temp = good_data['days_exposition'].apply(lambda x: pd.Timedelta(x, unit='D'))
good_data['month_sale'] = (good_data['first_day_exposition'] + temp).dt.month

# %%
good_data.pivot_table(index='month_sale', values=['last_price']).plot();

# %%
good_data['month_sale'].hist();

# %% [markdown]
# Судя по графикам, дешевле всего покупать жилье летом. По гистограмме видно, что спрос на жилье летом меньше всего, поэтому и продают дешевле. В начале года и весной цена выше, т.к. спрос большой. Значит правильно говорят, что жилье в Новый Год продается чаще.

# %% [markdown]
# Проверим цены в зависимости от дня, месяца и года публикации.

# %%
good_data.pivot_table(index='day_of_week', values='last_price').reset_index() \
.plot(x='day_of_week', y='last_price', kind='line', figsize=(9, 12));
good_data.pivot_table(index='month', values='last_price').reset_index() \
.plot(x='month', y='last_price', kind='line', figsize=(9, 12));
good_data.pivot_table(index='year', values='last_price').reset_index() \
.plot(x='year', y='last_price', kind='line', figsize=(9, 12));

# %% [markdown]
# Графики показывают:
#  - квартиры дешевле выставляют на выходных;
#  - дешевое жилье выставляют в июне, октябре, декабре, а дороже всего в апреле и сентябре;
#  - в 2017 году был кризис, соответственно цена на недвижимость упала, с тех пор росла высокими темпами.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно проанализировал зависимость от категориальных признаков, продолжай в том же духе!

# %% [markdown]
# <font color='orange'> Добавил новые зависимости, но в задании указано выявить зависимость от дня/месяца/года, а не дня/недели/месяца </font>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# В задании сказано, что нужно также проанализировать зависимость цены от:
#
# 1) Дня недели, в который объявление было размещено.
#
# 2) Недели, в который объявление было размещено.
#
# 3) Месяца, в который объявление было размещено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все снова верно.

# %% [markdown]
# #### Цена квадратного метра в населенных пунктах

# %% [markdown]
# Сгруппируем данные по топонимам и выведем первые 10 с наибольшим количеством объявлений.

# %%
top_locality = good_data.groupby('locality_name')['index'].count().sort_values(ascending=False).reset_index().head(10)

# %% [markdown]
# Добавим их в отдельный список.

# %%
top_locality_list = top_locality['locality_name'].to_list()

# %% [markdown]
# Посчитаем средннюю стоимость квадратного метра по этим населенным пунктам.

# %%
good_data.query('locality_name.isin(@top_locality_list)').pivot_table(index='locality_name', values='square_price') \
.sort_values(by='square_price', ascending=False)
# Out:
#                   square_price
# locality_name
# Санкт-Петербург  109731.675127
# Пушкин           102418.538390
# Кудрово           95643.130167
# Парголово         89997.383174
# Мурино            86293.791370
# Шушары            78753.495441
# Колпино           75306.918311
# Гатчина           68863.471245
# Всеволожск        68811.495549
# Выборг            58370.059497

# %% [markdown]
# Найдем самый "дорогой" и "дешевый" город.

# %%
cities_mean_price = good_data.pivot_table(index='locality_name', values='square_price') \
.sort_values(by='square_price', ascending=False)
print(cities_mean_price.head(1))
print(cities_mean_price.tail(1))
# Out:
#                square_price
# locality_name
# Лисий Нос         113728.35
#                square_price
# locality_name
# Старополье         11206.22

# %% [markdown]
# Самое дорогое жилье в н.п. Лисий Нос, самое дешевое в Старополье.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Именно так, все верно!

# %% [markdown]
# #### Цена от расстояния до центра Санкт-Петербурга

# %% [markdown]
# Посмотрим на распределение цен за квадратный метр в Санкт-Петербурге в зависимости от расстояния до центра города.

# %%
peter_km_price = good_data.query('locality_name == "Санкт-Петербург"') \
.pivot_table(index='city_centers_nearest_km', values='square_price').reset_index()
peter_km_price
# Out:
#     city_centers_nearest_km   square_price
# 0                       0.0  116698.229000
# 1                       1.0  145694.961415
# 2                       2.0  130011.011799
# 3                       3.0  116696.761528
# 4                       4.0  126742.755080
# 5                       5.0  133948.386319
# 6                       6.0  131327.683215
# 7                       7.0  127777.120570
# 8                       8.0  121180.596065
# 9                       9.0  112410.330628
# 10                     10.0  111317.953328
# 11                     11.0  106853.229210
# 12                     12.0  108221.268514
# 13                     13.0  108753.742100
# 14                     14.0  104144.876574
# 15                     15.0  104108.007078
# 16                     16.0  100138.574586
# 17                     17.0   97707.506816
# 18                     18.0   96804.024955
# 19                     19.0   99107.333286
# 20                     20.0  101399.172308
# ...

# %% [markdown]
# Ближе к центру — дороже метр.

# %%
peter_km_price.plot(x='city_centers_nearest_km', y='square_price', kind='line', figsize=(9, 12));

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно рассчитал и построил график, на графике стоило объединить точки линиями или построить столбчатую диаграмму.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В данной работе проводился анализ данных объявлений о продаже квартир сервиса Яндекс.Недвижимость.

# %% [markdown]
# Данные были изучены, приведены типы, заполнены пропуски, выявлены и исправлены аномальные значения.

# %% [markdown]
# Для упрощенной работы, данные были сгруппированы, добавлены новые столбцы. Данные были визуализированы при помощи гистограмм, графиков, матрицы распределения.

# %% [markdown]
# Анализ данных был нацелен на выявление некоторых зависимостей цены:
#  - цены от площадей (общей, жилой и кухни) — больше площадь, больше цена;
#  - цены от этажа (первый, последний, другой) — первый этаж в среднем намного дешевле средних или последнего;
#  - цены от времени продажи — квартире чаще продаются зимой и весной (тогда цена на них выше) и реже летом (цена становится ниже);
#  - цены от населенного пункта;
#  - цены от расстояния до центра города (ближе к центру — выше цена).

# %% [markdown]
# При анализе площадей было выявлено, что есть очевидная кореляция между общей площадью и жилой. При этом площадь кухни обычно редко превышает 20 квадратных метров.

# %% [markdown]
# При анализе этажей, выявлено, что большая часть квартир расположена до 10 этажа.

# %% [markdown]
# В выходные публикуются самые дешевые квартиры.

# %% [markdown]
# В обозриваемом периоде, недвижимость дешевле всего стоила в 2017 году, далее цены на недвижимость росли.

# %% [markdown]
# Также была выявлена средняя продолжительность продажи квартиры, она составила примерно 100 дней.

# %% [markdown]
# Самые дорогие квартиры Ленинградской области в н.п. Лисий Нос, самые дешевые в Старополье.

# %% [markdown]
# Также рекомендуется в данных рассмотреть зависимость цены от типа жилья (апартаменты/жилой фонд/студии/планировка) и обработать аномалии с учетом этих признаков.

# %% [markdown]
# <font color='orange'> Немного изменил общий вывод </font>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В итоговом выводе нужно достаточно подробно написать основные пункты выявленных зависимостей. Стоит доработать вывод с учетом моих комментариев по ходу работы. В итоговом выводе также старайся оставлять рекомендации для последующих шагов. Например рекомендации, что можно обработать и проанализировать другие признаки, на что твоим коллегам стоить обратить внимание.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный вывод, все четко, понятно и структурировано. Вывод в полной мере отражает существующие зависимости, и по нему можно принимать дальнейшие решения.
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Я уверен, что ты приложил все усилия, чтобы сделать этот проект. Это видно по твоей работе, а сформулированные выводы отражают, насколько успешно ты осваиваешь материал.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Ты полностью следовал всем этапам выполнения задания и справился почти со всем. Хорошая работа!
# * Отдельно выделю некоторые выводы, которые ты смог сформулировать абсолютно точно!
# * У тебя опрятный и читаемый код. Возможно это звучит банально, однако при работе с чужим кодом это крайне важно)
#
#
# **На что стоит обратить внимание🤓**:
#
# * Важно доработать итоговый вывод.
# * Нужно корректно обработать признаки.
# * Дополни анализ зависимости цены параметрами времени размещения.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Ты отлично справился с данной работой! Видно, как ты успешно осваиваешь материал, применяешь полученные знания на практике. Мне было очень приятно проверять твою работу, надеюсь, мои комментарии и советы были для тебя полезными.
#
# **Желаю удачи в последующем обучении и исследованиях!**😉
